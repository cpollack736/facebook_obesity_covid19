# %% [markdown]
# # Libraries and Packages

# %%
from bertopic import BERTopic

# %% [markdown]
# # Data

# %%
file_path = "/Users/catherinepollack/Documents/dartmouth/research/aim3_facebook_covid19_obesity/data"
topic_model = BERTopic.load("220313_bert_topic_model_instagram")

# %%
topic_model.get_topic_info()[0:20]
# Out:
#     Topic  Count                                               Name
# 0      -1  34975                                   -1_the_to_and_of
# 1       0   4819                                     0_my_was_me_im
# 2       1   3567                                   1_de_que_para_em
# 3       2   2964                                2_cats_dog_dogs_pet
# 4       3   2513                             3_dan_yang_berat_untuk
# 5       4   1944                    4_children_kids_childhood_child
# 6       5   1909                 5_surgery_bariatric_gastric_sleeve
# 7       6   1767                      6_sugar_added_drinks_fructose
# 8       7   1606                  7_covid19_virus_covid_coronavirus
# 9       8   1286                        8_tea_coffee_green_turmeric
# 10      9   1057                    9_meat_plantbased_vegan_animals
# 11     10   1054                      10_uae_qatar_doha_qatarbeauty
# 12     11   1005  11_tupmide_midekucultme_midebotoksu_gastrikbypass
# ...

# %%
for i in range(0,20):
    print(i)
    docs = topic_model.get_representative_docs()[i]
    for d in docs:
        print(d)
        print("-----")
    print("**********")
# Out:
# 0
# A public service announcement.
# .
# We have no idea what the story is behind each person we see.
# .
# Yes, we’re conditioned to judge because of the stigma against obesity.
# .
# So what? Work hard to fight those biases.
# .
# You have no idea what that person has gone through. You have no idea what they’re currently going through.
# .
# So don’t be so quick to judge. Smile. Offer a friendly hand. Just stop being a dick.
# .
# .
# .
# .
# .
# .
# #weightlossideas #weightlossrecipes #weightlossupport #weightlosss #fatlosstips #fatlossjourney #fatlossdiet #fatlosstransformation #iifymrecipes #iifymweightloss #flexibledietinglifestyle
# -----
# “The way that my clients explain it to me is that when they were overweight or were experiencing obesity, they were so large, but they felt invisible.” - Powerful words by my next inspiring Womenspired™️ guest, Dr. Rachel Goldman (@drrachelnyc), Clinical Psychologist who specializes in health behavior change. 💜
# .
# ...
